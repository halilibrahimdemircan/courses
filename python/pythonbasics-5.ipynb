# %%
isim = "Halil İbrahim"

a = list(isim)
print(a)
# Out:
# ['H', 'a', 'l', 'i', 'l', ' ', 'İ', 'b', 'r', 'a', 'h', 'i', 'm']

# %%
warning = 'You must quit smoking!'

print(len(list(warning)))
# Out:
# 22

# %%
print(list(warning))
# Out:
# ['Y', 'o', 'u', ' ', 'm', 'u', 's', 't', ' ', 'q', 'u', 'i', 't', ' ', 's', 'm', 'o', 'k', 'i', 'n', 'g', '!']

# %%
city = ['New York', 'Stockholm', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']
city[1] = 'Melbourne'

# %%
city
# Out:
# ['New York', 'Melbourne', 'Istanbul', 'Seoul', 'Sydney', 'Addis Ababa']

# %%
city.insert(3, 12)

# %%
city
# Out:
# ['New York',
#  'Melbourne',
#  'Istanbul',
#  12,
#  'Ankara',
#  'Seoul',
#  'Sydney',
#  'Addis Ababa']

# %%
x = 2
y = 3
print(f"burada neler oluyor... {x**y}")
# Out:
# burada neler oluyor... 8

# %%
name = "MARIAM"
print(f"My name is {name.capitalize()}")
# Out:
# My name is Mariam

# %%
isim = "ALLAH NE VERDİYSE"
print(f"Benim adım {isim.capitalize()}")
# Out:
# Benim adım Allah ne verdi̇yse

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = (
  f"Hi {name}." \
  f" You are one of the {job}." \
  f" Your job is{job}"
)

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = f"Hi {name}." \
  f" You are one of the {job}." \
  f" Your job is{job}"

# %%
message
# Out:
# 'Hi Joseph. You are one of the teachers. Your job isteachers'

# %%
"ahmet".title()
# Out:
# 'Ahmet'

# %%
"ahmet".capitalize()
# Out:
# 'Ahmet'

# %%
name = "Susan"
age = "young"
gender = "lady"
school = "CLRWY IT university"

output = (
    f"{name} is a {age}"
    f""
)

# %%
city = "SARAJEVO"

print(f"I live in {city.capitalize()}")
# Out:
# I live in Sarajevo

# %%
word = 'clarusway'

n = 3
front = word[:n]
back = word[(n+1):9]
print(front + back
# Out:
# clausway

# %%
name = "Clarusway"
print(name.lower())
print(name) # burada tekrar atama yapılmazsa değişmez
name = "Clarusway".lower()
print(name) # strings are immutable değiştirilemez
# Out:
# clarusway
# Clarusway
# clarusway

# %%
# SEARCHING A STRING
text = "www.clarusway.com"
print(text.endswith(".com"))
print(text.startswith("https:"))
# Out:
# True
# False

# %%
text.isidentifier()
# Out:
# False

# %%
a = "clarusway"

# %%
a.replace("a","x")
# Out:
# 'clxruswxy'

# %%
a.replace("a","x",1)
# Out:
# 'clxrusway'

# %%
sentence = "          Bugün sabah erken kalktım akşama kadar ders çalıştım. Sonra zabaha gada yine ders çalıştım.        "

# %%
print(sentence.strip())
print(sentence) # sadece baştan ve sondan spaceleri atar
# Out:
# Bugün sabah erken kalktım akşama kadar ders çalıştım. Sonra zabaha gada yine ders çalıştım.
#           Bugün sabah erken kalktım akşama kadar ders çalıştım. Sonra zabaha gada yine ders çalıştım.

# %%
print(sentence.lstrip("bugün"))
# Out:
#           Bugün sabah erken kalktım akşama kadar ders çalıştım. Sonra zabaha gada yine ders çalıştım.

# %%
text = "tyou can learn almost everything in pre-classz"
text = text.upper().strip("TZ")
print(text)
# Out:
# YOU CAN LEARN ALMOST EVERYTHING IN PRE-CLASS
